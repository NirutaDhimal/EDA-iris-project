# %% [markdown]
# # Iris Flower Dataset

# %% [markdown]
# ##### loading the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


#Load iris.csv into a pandas dataFrame.

iris = pd.read_csv('iris.csv' )
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 1.2 Some High Level Statistics

# %%
#How many data point and features?
print(iris.shape)
# Out:
# (150, 5)

# %%
#what are the coloumn name in dataset?
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#How many data points for each class are present?
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# 2 Objective
#
# To find whether the flower belongs to sestosa or virginica or versicolor species

# %% [markdown]
# 3. Univariate Analysis

# %% [markdown]
# 3.1 PDF

# %%
# sepal_length
sns.FacetGrid(iris , hue = 'species' , height = 6).map(sns.distplot , 'sepal_length').add_legend();
plt.show();

# %% [markdown]
# Conclusion
# 1. Versicolor and virginica species are highly overalapped so they cannot be distinguished using sepal_length.
# 2. Similarly flower having sepal_length 4 to 4.9 cm have high chances of being in setosa species.

# %%
#sepal_width
sns.FacetGrid(iris , hue = 'species' , height = 6).map(sns.distplot , 'sepal_width').add_legend();
plt.show();

# %% [markdown]
# Conclusion
# 1. As the graph is highly overlapped sepal_width cannot be used to distinguish the species.

# %%
#petal_length
sns.FacetGrid(iris , hue = 'species' , height = 6).map(sns.distplot , 'petal_length').add_legend();
plt.show();

# %% [markdown]
# Conclusion
# 1. Flowers having petal length between 1 and 2.1 cm belong to setosa species.
# 2. Iris flowers having petal length between 2.1 to 3.5 cm have high chances of being versicolor species.
# 3. Iris flowers having petal length betweem 6 to 8 cm have high chances of being virginica species.

# %%
#petal_width
sns.FacetGrid(iris , hue = 'species' , height = 6).map(sns.distplot , 'petal_width').add_legend();
plt.show();

# %% [markdown]
# Conclusion
# 1. Flowers having petal length 0.25 and 0.35 are likely to be in setosa species.
# 2. Iris flowers having petal length between 0.7 to 1 cm have high chances of being versicolor species.
# 3. Iris flowers having petal length betweem 2 to 3 cm have high chances of being virginica species.

# %% [markdown]
# #### 3.2 CDF

# %%
class_1 = iris.loc[iris["species"] == 'setosa']
class_2 = iris.loc[iris["species"] == 'versicolor']
class_3 = iris.loc[iris["species"] == 'virginica']

# %%
#sepal_length corresponding to class_1

counts, bin_edges = np.histogram(class_1['sepal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf, label = 'cdf')
plt.xlabel('sepal length')
plt.title("[CDF PLOT 1.1] Sepal length feature corresponding to class 1")
plt.legend()
plt.show()
# Out:
# [0.08 0.02 0.12 0.1  0.24 0.16 0.08 0.1  0.04 0.06]
# [4.3  4.45 4.6  4.75 4.9  5.05 5.2  5.35 5.5  5.65 5.8 ]

# %% [markdown]
# Conclusion
# 1. 75 % of flowers with sepal length less than or equal to 5.2 cm are in setosa species.

# %%
#sepal_length corresponding to class_2

counts, bin_edges = np.histogram(class_2['sepal_length'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf, label = 'cdf')
plt.xlabel('sepal length')
plt.title("[CDF PLOT 1.2] Sepal length feature corresponding to class 2")
plt.legend()
plt.show()
# Out:
# [0.08 0.02 0.12 0.2  0.1  0.16 0.1  0.06 0.1  0.06]
# [4.9  5.11 5.32 5.53 5.74 5.95 6.16 6.37 6.58 6.79 7.  ]

# %%
#sepal_length corresponding to class_3
counts,bin_edges = np.histogram(class_3['sepal_length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('sepal length')
plt.title("[CDF PLOT 1.3]Sepal length feature corresponding to class 3")
plt.legend()
plt.show()
# Out:
# [0.02 0.   0.1  0.1  0.16 0.18 0.2  0.1  0.02 0.12]
# [4.9 5.2 5.5 5.8 6.1 6.4 6.7 7.  7.3 7.6 7.9]

# %% [markdown]
# Conclusion
# 1. 80 % of Iris flowers having sepal length less than or equal to 7 cm are in virginica species.

# %%
#sepal_width corresponding to class_1
counts,bin_edges = np.histogram(class_1['sepal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('sepal width')
plt.title("[CDF PLOT 2.1]Sepal width feature corresponding to class 1")
plt.legend()
plt.show()
# Out:
# [0.02 0.   0.02 0.2  0.14 0.3  0.12 0.12 0.04 0.04]
# [2.3  2.51 2.72 2.93 3.14 3.35 3.56 3.77 3.98 4.19 4.4 ]

# %%
#sepal_width corresponding to class_2
counts,bin_edges = np.histogram(class_2['sepal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('sepal width')
plt.title("[CDF PLOT 2.2]Sepal width feature corresponding to class 2")
plt.legend()
plt.show()
# Out:
# [0.02 0.04 0.12 0.08 0.06 0.22 0.14 0.22 0.06 0.04]
# [2.   2.14 2.28 2.42 2.56 2.7  2.84 2.98 3.12 3.26 3.4 ]

# %%
#sepal_width corresponding to class_3
counts,bin_edges = np.histogram(class_3['sepal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('sepal width')
plt.title("[CDF PLOT 2.3]Sepal width feature corresponding to class 3")
plt.legend()
plt.show()
# Out:
# [0.02 0.08 0.04 0.24 0.04 0.32 0.16 0.04 0.02 0.04]
# [2.2  2.36 2.52 2.68 2.84 3.   3.16 3.32 3.48 3.64 3.8 ]

# %%
#petal_height corresponding to class_1
counts,bin_edges = np.histogram(class_1['petal_length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal length')
plt.title("[CDF PLOT 3.1]Petal length feature corresponding to class 1")
plt.legend()
plt.show()
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %% [markdown]
# Conclusion
# 1. 75 % of iris flower with petal length less than or equal to 1.57 cm belongs to setona species.

# %%
#petal_height corresponding to class_2
counts,bin_edges = np.histogram(class_2['petal_length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal length')
plt.title("[CDF PLOT 3.2]Petal length feature corresponding to class 2")
plt.legend()
plt.show()
# Out:
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# Conclusion
# 1. Nearly 60 % of iris flower with petal length less than or equal to 4.5 cm belongs to versicolor species.

# %%
#petal_height corresponding to class_3
counts,bin_edges = np.histogram(class_3['petal_length'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal length')
plt.title("[CDF PLOT 3.3]Petal length feature corresponding to class 3")
plt.legend()
plt.show()
# Out:
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]

# %%
#petal_width corresponding to class_1
counts,bin_edges = np.histogram(class_1['petal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal width')
plt.title("[CDF PLOT 4.1]Petal width feature corresponding to class 1")
plt.legend()
plt.show()
# Out:
# [0.1  0.   0.58 0.14 0.   0.   0.14 0.   0.02 0.02]
# [0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6 ]

# %% [markdown]
# Conclusion
# 1. 80% of iris flower with petal width less than or equal to 0.3cm belongs to setosa species.

# %%
#petal_width corresponding to class_2
counts,bin_edges = np.histogram(class_2['petal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal width')
plt.title("[CDF PLOT 4.2]Petal width feature corresponding to class 2")
plt.legend()
plt.show()
# Out:
# [0.14 0.06 0.1  0.26 0.   0.14 0.2  0.06 0.02 0.02]
# [1.   1.08 1.16 1.24 1.32 1.4  1.48 1.56 1.64 1.72 1.8 ]

# %% [markdown]
# Conclusion
# 1. About 55% of iris flower with petal width less than or equal to 1.33 cm belongs to versicolor species.

# %%
#petal_width corresponding to class_3
counts,bin_edges = np.histogram(class_3['petal_width'], bins=10, density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],cdf,label = 'cdf')
plt.xlabel('petal width')
plt.title("[CDF PLOT 4.3]Petal width feature corresponding to class 3")
plt.legend()
plt.show()
# Out:
# [0.06 0.02 0.02 0.22 0.1  0.12 0.12 0.06 0.16 0.12]
# [1.4  1.51 1.62 1.73 1.84 1.95 2.06 2.17 2.28 2.39 2.5 ]

# %% [markdown]
# #### 3.3 Box Plot

# %%
#Box plot using feature sepal_length
sns.boxplot(x='species',y='sepal_length', data=iris)
plt.grid()
plt.title("Box plot using feature sepal length")
plt.show()

# %% [markdown]
# Conclusion
# 1. Clearly from figure setosa class is not overlapping any other class.Hence, we can conclude that iris flower with sepal length between 4.8 cm to 5.2 cm belongs to setosa species.
# 2. sepal_length feature can be used to distinguish setosa species from other two species.

# %%
#Box plot using feature sepal_width
sns.boxplot(x='species',y='sepal_width', data=iris)
plt.grid()
plt.title("Box plot using feature sepal width")
plt.show()

# %%
#Box plot using feature petal_length
sns.boxplot(x='species',y='petal_length', data=iris)
plt.grid()
plt.title("Box plot using feature petal  length")
plt.show()

# %% [markdown]
# Conclusion
# 1. Clearly from figure we can conclude that petal length feature can be used to distinguish the species of iris flower as no classes are overlapping.
# 2. Iris flower with petal length 1.3 to 1.6 cm belongs to setosa species.
# 3. Iris flower with petal length 4 to 4.5 cm belongs to versicolor species.
# 4 Similarly, Iris flower with petal length 5.1 to 5.9 cm belongs to virginica species.

# %%
#Box plot using feature petal_width
sns.boxplot(x='species',y='petal_width', data=iris)
plt.grid()
plt.title("Box plot using feature petal width")
plt.show()

# %% [markdown]
# Conclusion
# 1. From figure we can see that no classes are overlapping so petal_width feature can be used to distinguish species of iris flower.

# %% [markdown]
# #### 3.4  Violin Plot

# %%
#Violin plot using feature sepal length
sns.violinplot(x='species',y='sepal_length', data=iris)
plt.grid()
plt.title("Violin plot using feature sepal length")
plt.show()

# %% [markdown]
# Conclusion
# 1. overlapping among different classes is seen

# %%
#violin plot using feature sepal width
sns.violinplot(x = 'species', y = 'sepal_width', data = iris)
plt.grid()
plt.title("violin plot using feature sepal width")
plt.show()

# %% [markdown]
# Conclusion
# 1. Overlapping among different classes is seen.

# %%
#violin plot using feature petal length
sns.violinplot(x = 'species', y = 'petal_length', data = iris)
plt.grid()
plt.title("violin plot using feature petal length")
plt.show()

# %% [markdown]
# Conclusion
# 1. As there is no overlapping of class setosa with other classes so petal_length can be used to distinguish setosa species from other species of iris flower.
# 2. Almost 40 to 50 % overlapping is seen between versicolor and virginica classes.

# %%
#violin plot using feature petal width
sns.violinplot(x = 'species', y = 'petal_width', data = iris)
plt.grid()
plt.title("violin plot using feature petal width")
plt.show()

# %% [markdown]
# Conclusion
# 1. Overlapping is seen between versicolor and virginica classes.

# %% [markdown]
# #### 4. Bivariate Plot

# %% [markdown]
# #### 4.1 Scatter Plot

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "sepal_length", "sepal_width").add_legend();
plt.title("Scatter plot of sepal_length VS sepal_width");
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "petal_length", "petal_width").add_legend();
plt.title("Scatter plot of petal_length VS petal_width");
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "sepal_length", "petal_width").add_legend();
plt.title("Scatter plot of sepal_length VS petal_width");
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "sepal_length", "petal_length").add_legend();
plt.title("Scatter plot of sepal_length VS petal_length");
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "sepal_width", "petal_width").add_legend();
plt.title("Scatter plot of sepal_width VS petal_width");
plt.show();

# %%
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=6).map(plt.scatter, "sepal_width", "petal_length").add_legend();
plt.title("Scatter plot of sepal_width VS petal_length");
plt.show();

# %% [markdown]
# #### 4.2 Pair Plot

# %%
# pairwise scatter plot: Pair-Plot
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species",x_vars =['sepal_length','sepal_width','petal_length','petal_width'],y_vars =['sepal_length','sepal_width','petal_length','petal_width'], height=4);
plt.suptitle("Pair-Plot of Iris Flower Data Set",size =26);
plt.show();

# %% [markdown]
# Conclusion
# 1. Petal length and petal width are the most useful feature while seperating various iris flowers.
# 2. Setosa species can be easily identified, while versicolor and virginca species have some overlapping.
